# %%
import statistics
dividend_gaps_in_days_list = [367, 274, 847, 366, 431]

# %%
mean = statistics.mean(dividend_gaps_in_days_list)
fmean = statistics.fmean(dividend_gaps_in_days_list)
geometric_mean = statistics.geometric_mean(dividend_gaps_in_days_list)
harmonic_mean = statistics.harmonic_mean(dividend_gaps_in_days_list)

# %%
median = statistics.median(dividend_gaps_in_days_list)
median_grouped = statistics.median_grouped(dividend_gaps_in_days_list)
mode = statistics.mode(dividend_gaps_in_days_list)
multimode = statistics.multimode(dividend_gaps_in_days_list)
quantiles = statistics.quantiles(dividend_gaps_in_days_list)

# %%
pstdev = statistics.pstdev(dividend_gaps_in_days_list) # better, because higher priority for continuation
pvariance = statistics.pvariance(dividend_gaps_in_days_list)
stdev = statistics.stdev(dividend_gaps_in_days_list)
variance = statistics.variance(dividend_gaps_in_days_list)

# %%
xxx = statistics.xxx(dividend_gaps_in_days_list)
xxx = statistics.xxx(dividend_gaps_in_days_list)
xxx = statistics.xxx(dividend_gaps_in_days_list)
xxx = statistics.xxx(dividend_gaps_in_days_list)

# %%
from statsmodels.stats.weightstats import DescrStatsW

weights = [5, 50, 3, 2, 1]
DescrStatsW(dividend_gaps_in_days_list, weights=weights, ddof=1).std
tmp = DescrStatsW(dividend_gaps_in_days_list, weights=weights, ddof=1)

# %%
sum([367*6.25, 274*4.0, 847*2.25, 366, 431*0.25])
# Out:
# 5769.25
