# %%
import pickle
from dividend_listing import DividendCompanyItem, DividendItem

# %%
path_to_pickle_file = 'c:\\GitHub\\Python\\gen\\dumps\\curr_settings_dividend_listing.pickle'
db_file = open(path_to_pickle_file, 'rb')
dict_from_pickle = pickle.load(db_file)
db_file.close()

# %%
print(repr(dict_from_pickle['items_list'][0]))
print(dict_from_pickle['items_list'][0].json())
print('---------------\n\n\n---------------')
[print(item.json()) for item in dict_from_pickle['items_list']]
# Out:
# ...
# {"bossa_instrument_url": "https://bossa.pl/notowania/instrumenty/ATP", "name_short": "ATP", "name_long": "ATLANTAPL", "sector_gpw": "GPW: Przemys\u0142 spo\u017cywczy", "sector_name": "Artyku\u0142y spo\u017cywcze", "dividends_list": ["{\"date\": \"2021-03-08T00:00:00\", \"percent\": 2.89, \"nominal\": 0.28, \"rights_issue\": 1.02972399, \"share_price_date\": null, \"share_price_nominal\": null}", "{\"date\": \"2020-03-06T00:00:00\", \"percent\": 3.51, \"nominal\": 0.19423, \"rights_issue\": 1.03636364, \"share_price_date\": null, \"share_price_nominal\": null}", "{\"date\": \"2019-06-06T00:00:00\", \"percent\": 16.84, \"nominal\": 0.937, \"rights_issue\": 1.20242915, \"share_price_date\": null, \"share_price_nominal\": null}", "{\"date\": \"2017-02-09T00:00:00\", \"percent\": 4.76, \"nominal\": 0.25717, \"rights_issue\": 1.05, \"share_price_date\": null, \"share_price_nominal\": null}", "{\"date\": \"2016-02-09T00:00:00\", \"percent\": 7.66, \"nominal\": 0.4824, \"rights_issue\": 1.
# ...
