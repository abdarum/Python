# %%
from pandas_datareader import data as pdr

# %%
df = pdr.DataReader("^DJI", "stooq")

# %%
df = pdr.DataReader("^ATP.PL", "stooq")

# %%
df = pdr.DataReader("pge.PL", "stooq")

# %%
df = pdr.DataReader("ATP.PL", "stooq")

# %%
df = pdr.DataReader("ZWC.PL", "stooq")

# data files
# https://stooq.com/db/h/

# %%
df = pdr.DataReader("ZWC.PL", "stooq", '2002-07-02', '2002-07-02')
df
# Out:
#               Open    High     Low   Close  Volume
# Date
# 2002-07-02  116.11  116.29  114.86  116.29     720

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df.iloc[0]['Close']
# Out:
# 116.29
